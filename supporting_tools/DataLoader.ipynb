# %% [markdown]
# # Data Loader
# * loads csv file, expected to have set structure of columns even if not all used
# * cleans data:
# *   1) find and remove duplicates
# *   2) clean up addresses
# *   3) get lats/longs
# *   4) calculate additional columns
# * uploads to db

# %%
from sqlalchemy.orm import sessionmaker
from models import connect_db, PointsOfInterest, ArchitecturalStyles, Architects,POICategories
import pandas as pd
import re

# %%
from config import BaseConfig
from utils import *

# %%
import logging
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)
logging.basicConfig(filename='../logs/initdataload.log',level=logging.INFO)

# %%
def make_simple_poi(org_type):
    if org_type == 'Plaque':
        return org_type
    elif org_type == 'Monument':
        return 'Art'
    else:
        return 'Building'

# %%
def clean_build_year(year):
    if pd.isna(year) or year == None or len(year) < 4:
        return ''
    strip_words = ['unknown', 'circa ', 'abt ', 'about']
    for word in strip_words:
        year=year.replace(word, '')
    return year[0:4]

# %%
# try to find points outside of Toronto
def find_points_outside_TO(df, fix_address=False, dist=50, starting_lat=43.656287,starting_long= -79.380898):
    ''' Find points more than 50KM from downtown Toronto (Yonge Dundas Square is default) and try to update'''
    df=find_dist(df, starting_lat, starting_long)
    for ix, row in df[df['dist_start']>dist].iterrows():
        #print(f"{row['poi_id'], row['name']} is outside of Toronto")
        logging.debug(f"{row['poi_id'], row['name']} is outside of Toronto")
        #update_coords(row['poi_id'], fix_address)
        lat, long = get_lats_longs(row)
        df_poi.loc[index, 'latitude']= lat
        df_poi.loc[index, 'longitude']= long
    return df

# %%
def add_features(df):
    df['cleaned_year']=df['build_year'].apply(lambda x: clean_build_year(x))
    df['cleaned_year']=pd.to_numeric(df['cleaned_year'],errors='coerce',downcast='integer')
    df['build_decade']= df['cleaned_year'].apply(lambda x: x//10*10 )
    df['poi_type_simple'] = df['poi_type'].apply(lambda x: make_simple_poi(x))
    return df

# %%
def load_init_data():
    df_poi = pd.read_csv('../init_data/pois.csv' )
    df_architects = pd.read_csv('../init_data/architects.csv' )
    df_cats = pd.read_csv('../init_data/poi_cats.csv' )
    df_styles= pd.read_csv('../init_data/architectural_styles.csv' )
    return df_poi, df_architects, df_cats, df_styles

# %%
def data_clean_up(df_poi):
    '''
    Load from CSV
    Drop duplicates
    Clean up address
    Find missing lat/long coords
    Find spots outside Toronto and 
    add new features
    '''
    #df_poi=load_init_data()
    df_poi=df_poi.drop_duplicates(subset=['name', 'address','source','external_url'], keep='last')
    df_poi['address']=df_poi.apply(lambda row: cleanup_address(row['name'], row['address'], logging), axis=1)
    for index, row in df_poi[pd.isna(df_poi['latitude']) | pd.isna(df_poi['longitude'])].iterrows():
        lat, long = get_lats_longs(row)
        df_poi.loc[index, 'latitude']= lat
        df_poi.loc[index, 'longitude']= long
    df_poi=find_points_outside_TO(df_poi)
    df_poi = add_features(df_poi)
    return df_poi

# %%
df_poi, df_architects, df_cats, df_styles=load_init_data()
df_poi=data_clean_up(df_poi)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\blahjays\Documents\GitHubCode\Personal_Public\TorontoWalkGenerator\web\utils.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['dist_start'] = avail_points
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df_poi.head()
# Out:
#    poi_id                                         name build_year  \
# 1       2  Walter Seymour Allward, R.C.A.  1876 - 1955        345
# 2       4  Walter Seymour Allward, R.C.A.  1876 - 1955        NaN
# 3    7368                  Betty Oliphant  1918 - 2004        NaN
# 4    7370      Dr. Mary O'Riordan, D.V.M.  1925 - 1993        NaN
# 5    7371                    Roger Abbott  1946 - 2011        NaN
#
#    demolished_year                                 address   latitude  \
# 1              NaN   43 Amelia Street, Toronto, ON, Canada  43.667614
# 2              NaN  137 Amelia Street, Toronto, ON, Canada  43.668273
# 3              NaN  137 Amelia Street, Toronto, ON, Canada  43.668240
# 4              NaN  160 Amelia Street, Toronto, ON, Canada  43.668870
# 5              NaN  132 Amelia Street, Toronto, ON, Canada  43.668470
#
#    longitude                                       external_url image_url  \
# 1 -79.366896  http://www.cabbagetownpeople.ca/person/walter-...       NaN
# 2 -79.363974  http://www.cabbagetownpeople.ca/person/walter-...       NaN
# 3 -79.363880  http://www.cabbagetownpeople.ca/person/betty-o...       NaN
# 4 -79.362990  http://www.cabbagetownpeople.ca/person/mary-or...       NaN
# 5 -79.364410  http://www.cabbagetownpeople.ca/person/roger-a...       NaN
#
#   heritage_status current_use poi_type                           source  \
# 1           other         NaN      NaN  http://www.cabbagetownpeople.ca
# 2             NaN         NaN      NaN  http://www.cabbagetownpeople.ca
# 3             NaN         NaN   Plaque  http://www.cabbagetownpeople.ca
# 4             NaN         NaN   Plaque  http://www.cabbagetownpeople.ca
# 5             NaN         NaN   Plaque  http://www.cabbagetownpeople.ca
#
#                                              details  dist_start  \
# 1                                                NaN    1.690953
# 2                                                NaN    1.907115
# 3  World-Renowned Innovator of Ballet Education. ...    1.909954
# 4  Pioneering Veterinarian.  Born in Ennis, Count...    2.010212
# 5  Comedian and Actor, Co-Founder of the Royal Ca...    1.897606
#
#    cleaned_year  build_decade poi_type_simple
# 1           NaN           NaN        Building
# 2           NaN           NaN        Building
# 3           NaN           NaN          Plaque
# 4           NaN           NaN          Plaque
# 5           NaN           NaN          Plaque

# %%
# need to stitch together different dfs

# %%
df_to_db_map={
    'name':'name',
    'build_year':'build_year'   ,
    'demolished_year' :'demolished_year',
    'address' :'address' ,
    'external_url':'external_url',
    'details': 'details',
    'image_url':'image_url',
    'heritage_status':'heritage_status',
    'current_use use':'current_use',
    'poi_type':'poi_type',
    'source': 'source', 
    'cleaned_year': 'build_year_clean',
    'build_decade': 'build_decade',
    'poi_type_simple': 'poi_type_simple',
    'latitude': 'latitude',
    'longitude': 'longitude'
}

# %%
df_poi.columns
# Out:
# Index(['poi_id', 'name', 'build_year', 'demolished_year', 'address',
#        'latitude', 'longitude', 'external_url', 'image_url', 'heritage_status',
#        'current_use', 'poi_type', 'source', 'details', 'dist_start',
#        'cleaned_year', 'build_decade', 'poi_type_simple'],
#       dtype='object')

# %%
def save_to_database_ORM(df):
    '''
    Saves scraped data to database using SqlAlchemy ORM
    Updates three tables: points_of_interest, archtectural_styles, architects
    The relationship between these tables is defined in models.py, so it automatically populates the poi_id column
    in the child tables with the poi_id of the main entry 
    '''
    
    for index, row in df.iterrows():
        
        poi_dict ={df_to_db_map[k]:v for k, v in row.items() if k in df_to_db_map.keys() and not pd.isnull(v)}
        #poi_dict['source']= site_root
        poi = PointsOfInterest(**poi_dict )
        old_poi_id =row['poi_id']
        
        # define style
        for ix2, astyle in df_styles[df_styles['poi_id']==old_poi_id].iterrows():
            #tyle=ArchitecturalStyles(style=row['Style'])
            style=ArchitecturalStyles(style=astyle['style'])
            poi.styles.append(style)
            
        for ix2, acat in df_cats[df_cats['poi_id']==old_poi_id].iterrows():
            cat = POICategories(category =acat['category'])
            poi.categories.append(cat)
            
        # architects (can be multiple)
        prev_company=""
        for ix2, anarct in df_architects[df_architects['poi_id']==old_poi_id].iterrows():
            if anarct['architect_name'] != prev_company and not 'Also see' in anarct['architect_name']:
                architect = Architects(architect_name= anarct['architect_name'].replace("'","''"))
                poi.architects.append(architect)
                prev_company=anarct['architect_name']
                print (anarct['architect_name'])
        print(poi.styles)
#         session.add(poi)
#         session.commit()

# %%
df_architects[df_architects['poi_id']==218]
# Out:
#     poi_id                                     architect_name
# 36     218  Bruce Kuwabara, Thomas Payne, Marianne McKenna...
# 37     218                               S.H. Maw, Associates
# 38     218                              George and Moorehouse

# %%
df_cats[df_cats['poi_id']==5]
# Out:
# Empty DataFrame
# Columns: [poi_id, category]
# Index: []

# %%
save_to_database_ORM(df_poi[df_poi['poi_id']==8])
# Out:
# [<models.ArchitecturalStyles object at 0x000001772D4076D8>]

# %%
df_poi[df_poi['poi_id']!=8]
# Out:
#       poi_id                                            name       build_year  \
# 1          2     Walter Seymour Allward, R.C.A.  1876 - 1955              345
# 2          4     Walter Seymour Allward, R.C.A.  1876 - 1955              NaN
# 3       7368                     Betty Oliphant  1918 - 2004              NaN
# 4       7370         Dr. Mary O'Riordan, D.V.M.  1925 - 1993              NaN
# 5       7371                       Roger Abbott  1946 - 2011              NaN
# 6       7372                    Gordon Sinclair  1900 - 1984              NaN
# 7       7374              Allan Winton King, OC  1930 - 2009              NaN
# 8       7376                    Charles Sauriol  1904 - 1995              NaN
# 9       7377                 Oronhyatekha, M.D.  1841 - 1907              NaN
# 10      2600                            J. H. McKinnon House             1888
# 11      7401            Corporal Ainsworth Dyer  1977 - 2002              NaN
# 12      7406               Fraser Mustard, M.D.  1927 - 2011              NaN
# 13      7408           Charles William Jefferys  1869 - 1951              NaN
# 14      7410                   Richard Bradshaw  1944 - 2007              NaN
# 15      7413                       Doug Henning  1947 - 2000              NaN
# 16      3309                                121 Major Street             1885
# 17      7366              Ernest Thompson Seton  1860 - 1946              NaN
# 18      7369                     Allen Yen, PhD  1925 - 1993              NaN
# 19      7373               Patricia Anne Watson  1930 - 2015              NaN
# 20      7375  Lieutenant Francis Gwillim Simcoe  1791 - 1812              NaN
# 21      7378             Dr.  Rowena Hume, M.D.  1877 - 1966              NaN
# 22      7379                  Sarah Anne Curzon  1833 - 1898              NaN
# 23      7380                     Benjamin Brick  1845 - 1913              NaN
# 24      7381                  Cabbagetown’s First People   -              NaN
# 22                NaN            274 Carlton Street, Toronto, ON, Canada
# 23                NaN            314 Carlton Street, Toronto, ON, Canada
# 24                NaN  Riverdale Park, Winchester Street, Toronto, ON...
# 25                NaN             31 Hillcrest Park, Toronto, ON, Canada
# 26                NaN            2 Lancaster Avenue, Toronto, ON, Canada
# 27                NaN            20 Metcalfe Street, Toronto, ON, Canada
# 28                NaN            25 Metcalfe Street, Toronto, ON, Canada
# 29                NaN             3 Metcalfe Street, Toronto, ON, Canada
# 30                NaN            262 Ontario Street, Toronto, ON, Canada
# ...               ...                                                ...
# 4356              NaN          71-75 Mitchell Avenue Niagara Toronto, ON
# 4357              NaN   703-705 Richmond Street West Niagara Toronto, ON
# 4358              NaN       707 Richmond Street West Niagara Toronto, ON
# 4359              NaN       711 Richmond Street West Niagara Toronto, ON
# 4360              NaN       717 Richmond Street West Niagara Toronto, ON
# 4361              NaN   719-721 Richmond Street West Niagara Toronto, ON
# 4362              NaN   735-737 Richmond Street West Niagara Toronto, ON
# 4363              NaN     2-6 Wellesley Cottages Cabbagetown Toronto, ON
# 4364              NaN   753-755 Richmond Street West Niagara Toronto, ON
# 4365              NaN           229 River Street Cabbagetown Toronto, ON
# 4366              NaN       236-246 River Street Cabbagetown Toronto, ON
# 4367              NaN              34 Rosedale Road Rosedale Toronto, ON
# 4368              NaN   294-296 Sackville Street Cabbagetown Toronto, ON
# 4369              NaN       298 Sackville Street Cabbagetown Toronto, ON
# 4370              NaN     95 Scollard Street Bloor-Yorkville Toronto, ON
# 4371              NaN     161-165 Sixth Street New Toronto Etobicoke, ON
# 4372              NaN     173-175 Sixth Street New Toronto Etobicoke, ON
# 4373              NaN     177-179 Sixth Street New Toronto Etobicoke, ON
# 4374              NaN             106 Spadina Road The Annex Toronto, ON
# 4375              NaN           20 Spruce Street Cabbagetown Toronto, ON
# 4376              NaN           54 Spruce Street Cabbagetown Toronto, ON
# 4377              NaN        165 St. George Street The Annex Toronto, ON
# 4378              NaN        182 St. George Street The Annex Toronto, ON
# 4379              NaN        260 St. George Street The Annex Toronto, ON
# 4380              NaN          149 1/2  Stanley Ave Mimico Etobicoke, ON
# 4381              NaN      404-408 Sumach Street Cabbagetown Toronto, ON
# 4382              NaN            15 Sword Street Cabbagetown Toronto, ON
# 4383              NaN  307-311 Wellesley Street East Cabbagetown Toro...
# 4384              NaN  315-317 Wellesley Street East Cabbagetown Toro...
# 4385              NaN  319-321 Wellesley Street East Cabbagetown Toro...
#
#        latitude  longitude                                       external_url  \
# 1     43.667614 -79.366896  http://www.cabbagetownpeople.ca/person/walter-...
# 2     43.668273 -79.363974  http://www.cabbagetownpeople.ca/person/walter-...
# 3     43.668240 -79.363880  http://www.cabbagetownpeople.ca/person/betty-o...
# 4     43.668870 -79.362990  http://www.cabbagetownpeople.ca/person/mary-or...
# 5     43.668470 -79.364410  http://www.cabbagetownpeople.ca/person/roger-a...
# 6     43.665450 -79.362970  http://www.cabbagetownpeople.ca/person/gordon-...
# 4370  43.671700 -79.391640  http://www.acotoronto.ca/show_building.php?Bui...
# 4371  43.602368 -79.504474  http://www.acotoronto.ca/show_building.php?Bui...
# 4372  43.602698 -79.504606  http://www.acotoronto.ca/show_building.php?Bui...
# 4373  43.602831 -79.504659  http://www.acotoronto.ca/show_building.php?Bui...
# 4374  43.672340 -79.406280  http://www.acotoronto.ca/show_building.php?Bui...
# 4375  43.663670 -79.366410  http://www.acotoronto.ca/show_building.php?Bui...
# 4376  43.663910 -79.365130  http://www.acotoronto.ca/show_building.php?Bui...
# 4377  43.670660 -79.400770  http://www.acotoronto.ca/show_building.php?Bui...
# 4378  43.669010 -79.400790  http://www.acotoronto.ca/show_building.php?Bui...
# 4379  43.673070 -79.402530  http://www.acotoronto.ca/show_building.php?Bui...
# 4380  43.614760 -79.494860  http://www.acotoronto.ca/show_building.php?Bui...
# 4381  43.667580 -79.363500  http://www.acotoronto.ca/show_building.php?Bui...
# 4382  43.664050 -79.360370  http://www.acotoronto.ca/show_building.php?Bui...
# 4383  43.668150 -79.368840  http://www.acotoronto.ca/show_building.php?Bui...
# 4384  43.668110 -79.368530  http://www.acotoronto.ca/show_building.php?Bui...
# 4385  43.668180 -79.368460  http://www.acotoronto.ca/show_building.php?Bui...
#
#                                               image_url  \
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10    http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16    http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# 30                                                  NaN
# ...                                                 ...
# 4356  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4357  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4358  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4359  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4360  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4361  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4362  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4363  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4364  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4365  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4366  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4367  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4368  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4369  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4370  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4371  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4372  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4373  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4374  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4375  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4376  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4377  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4378  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4379  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4380  http://www.acotoronto.ca/tobuilt_bk/php/buildi...
# 4381  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4382  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4383  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4384  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
# 4385  http://www.acotoronto.ca/tobuilt_bk/php/Buildi...
#
#                                        heritage_status  current_use  \
# 1                                                other          NaN
# 2                                                  NaN          NaN
# 3                                                  NaN          NaN
# 4                                                  NaN          NaN
# 5                                                  NaN          NaN
# 6                                                  NaN          NaN
# 7                                                  NaN          NaN
# 8                                                  NaN          NaN
# 9                                                  NaN          NaN
# 10                                   Heritage property  Residential
# 11                                                 NaN          NaN
# 12                                                 NaN          NaN
# 13                                                 NaN          NaN
# 14                                                 NaN          NaN
# 15                                                 NaN          NaN
# 16                                                 NaN  Residential
# 17                                                 NaN          NaN
# 18                                                 NaN          NaN
# 19                                                 NaN          NaN
# 20                                                 NaN          NaN
# 21                                                 NaN          NaN
# 22                                                 NaN          NaN
# 23                                                 NaN          NaN
# 24                                                 NaN          NaN
# 25                                                 NaN          NaN
# 26                                                 NaN          NaN
# 27                                                 NaN          NaN
# 28                                                 NaN          NaN
# 29                                                 NaN          NaN
# 30                                                 NaN          NaN
# ...                                                ...          ...
# 4356                                No heritage status          NaN
# 4357                                            Listed  Residential
# 4358                                No heritage status  Residential
# 4359                                 Heritage property  Residential
# 4360                                 Heritage property  Residential
# 4361                                            Listed  Residential
# 4362                                               NaN          NaN
# 4363                                 Heritage property  Residential
# 4364                                No heritage status          NaN
# 4365  Cabbagetown South Heritage Conservation District  Residential
# 4366  Cabbagetown South Heritage Conservation District  Residential
# 4362  James Lukin Robinson built 32 Garrison Common ...    2.513930
# 4363                                                NaN    1.800861
# 4364  James Lukin Robinson built 32 Garrison Common ...    2.557145
# 4365                                                NaN    1.963885
# 4366                                                NaN    1.937186
# 4367  First Occupant: Dr. Geoffrey Boydphy \r\r\r\n\...    2.182490
# 4368                                                NaN    1.527901
# 4369                                                NaN    1.529828
# 4370                                                NaN    1.919179
# 4371                                                NaN   11.633997
# 4372                                                NaN   11.624281
# 4373                                                NaN   11.620418
# 4374                                                NaN    2.715204
# 4375                                                NaN    1.427798
# 4376                                                NaN    1.528084
# 4377                                                NaN    2.262576
# 4378                                                NaN    2.138362
# 4379                                                NaN    2.553674
# 4380                                                NaN   10.288746
# 4381                                                NaN    1.882455
# 4382                                                NaN    1.867013
# 4383                                                NaN    1.638044
# 4384                                                NaN    1.649472
# 4385                                                NaN    1.659080
#
#       cleaned_year  build_decade poi_type_simple
# 1              NaN           NaN        Building
# 2              NaN           NaN        Building
# 3              NaN           NaN          Plaque
# 4              NaN           NaN          Plaque
# 5              NaN           NaN          Plaque
# 6              NaN           NaN          Plaque
# 7              NaN           NaN          Plaque
# 8              NaN           NaN          Plaque
# 9              NaN           NaN          Plaque
# 10          1888.0        1880.0        Building
# 11             NaN           NaN          Plaque
# 12             NaN           NaN          Plaque
# 13             NaN           NaN          Plaque
# 14             NaN           NaN          Plaque
# 15             NaN           NaN          Plaque
# 16          1885.0        1880.0        Building
# 17             NaN           NaN          Plaque
# 18             NaN           NaN          Plaque
# 19             NaN           NaN          Plaque
# 20             NaN           NaN          Plaque
# 21             NaN           NaN          Plaque
# 22             NaN           NaN          Plaque
# 23             NaN           NaN          Plaque
# 24             NaN           NaN          Plaque
# 25             NaN           NaN          Plaque
# 26             NaN           NaN          Plaque
# 27             NaN           NaN          Plaque
# 28             NaN           NaN          Plaque
# 29             NaN           NaN          Plaque
# 30             NaN           NaN          Plaque
# ...            ...           ...             ...
# 4356        1859.0        1850.0        Building
# 4357        1859.0        1850.0        Building
# 4358        1880.0        1880.0        Building
# 4359           NaN           NaN        Building
# 4360           NaN           NaN        Building
# 4361        1859.0        1850.0        Building
# 4362        1859.0        1850.0        Building
# 4363        1887.0        1880.0        Building
# 4364        1859.0        1850.0        Building
# 4365           NaN           NaN        Building
# 4366           NaN           NaN        Building
# 4367        1919.0        1910.0        Building
# 4368           NaN           NaN        Building
# 4369        1879.0        1870.0        Building
# 4370        1871.0        1870.0        Building
# 4371           NaN           NaN        Building
# 4372           NaN           NaN        Building
# 4373           NaN           NaN        Building
# 4374        1905.0        1900.0        Building
# 4375           NaN           NaN        Building
# 4376        1882.0        1880.0        Building
# 4377        1907.0        1900.0        Building
# 4378        1911.0        1910.0        Building
# 4379        1905.0        1900.0        Building
# 4380        1945.0        1940.0        Building
# 4381        1902.0        1900.0        Building
# 4382           NaN           NaN        Building
# 4383           NaN           NaN        Building
# 4384           NaN           NaN        Building
# 4385           NaN           NaN        Building
#
# [4377 rows x 18 columns]
