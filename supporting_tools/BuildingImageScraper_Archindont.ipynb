# %% [markdown]
# # Web Scrape labelled images of building styles

# %% [markdown]
# # Architectural Index for Ontario - Archindont
# * Archindont is a database of architectural information and citations to periodical articles and books about buildings in Toronto.
# * list of building types: http://archindont.torontopubliclibrary.ca/Arch/search.do;jsessionid=jzKVTS6juZ65uhz4EA9tv9K7
# http://archindont.torontopubliclibrary.ca/Arch/main.do

# %%
# Import libaries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import string
import re
import urllib
import os
import time
from datetime import datetime
import string

# %%
from sqlalchemy import create_engine, Column, Integer, String, Sequence, Float
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from models import connect_db, PointsOfInterest, ArchitecturalStyles, Architects,POICategories

# %%
# search by Builidng Type
main_page = 'http://archindont.torontopubliclibrary.ca/Arch/search.do?searchType=Typ&initial='
#style_url="http://www.acotoronto.ca/search_buildingsDB_d2.php"
site_root = "http://archindont.torontopubliclibrary.ca"
debug=False
buildings_list=[]
rerun_webscrape=False # rerun all  webscraping
populate_db = False # repopulate database

# %%
def load_page(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.text
    else:
        print(f"Error connecting: status code {response.status_code}")

# %%
def building_types_pages(type_url):
    '''
    Returns list of dictionaries where each dictionary is info about one building
    To Test: /Arch/buildingType.do;jsessionid=A2ZMTUjOxuCFc4yaAxah-Nws?type=Apartment+Houses&typeID=18'
    '''
    buildings=[]
    flags_dict = {
            'Address:':None,
            'Type of Building:': None,
            'Name of Building:': None,
            'Notes:':None,
            'Building completed': None,
            'Demolished': None,
           'Architects:': None
        }
    throw_flag = False
    flag = None

    
    type_url = f"{site_root}/{type_url}"
    html = load_page(type_url)
    soup = BeautifulSoup(html)
    for tag in soup.recursiveChildGenerator():
        if tag.name in ['th','td']:
            
            if tag.text == 'Address:' and flags_dict['Address:'] != None:
                # new building but skip the first building in the page
                buildings.append(flags_dict) # write out dict for prev building
                flags_dict = {
                    'Address:':None,
                    'Type of Building:': None,
                    'Name of Building:': None,
                    'Notes:':None,
                    'Building completed': None,
                    'Demolished': None,
                   'Architects:': None
                }
            if throw_flag:
               # print(f"{flag} {tag.text.strip()}")
                flags_dict[flag] = tag.text.strip()
                throw_flag = False
            if tag.text.strip() in flags_dict.keys():
               # print(tag.text)
                throw_flag = True
                flag = tag.text.strip()

    return buildings

# %%
def run_webscrape():
    for char in string.ascii_uppercase[25]:
        letter_url = f"{main_page}{char}"
        html = load_page(letter_url)
        soup = BeautifulSoup(html)
        bld_types = soup.find('form', {'name':'SearchResultsForm'}).findChildren('li')
        for style in bld_types:
            bld_type_url = style.find('a').get_attribute_list('href')[0]
            buildings_list.extend(building_types_pages(bld_type_url))
            time.sleep(5)
        bld_df = pd.DataFrame(buildings_list)
        bld_df.to_csv('../data/archidont_buildings_'+ str(char) + str(round(time.time(),0)) + '.csv')

# %%
def save_to_database_ORM(session, df):
    '''
    Saves scraped data to database using SqlAlchemy ORM
    Updates three tables: points_of_interest, archtectural_styles, architects
    The relationship between these tables is defined in models.py, so it automatically populates the poi_id column
    in the child tables with the poi_id of the main entry 
    '''
    
    for index, row in df.iterrows():
        
        poi_dict ={df_to_db_map[k]:v for k, v in row.items() if k in df_to_db_map.keys() and not pd.isnull(v)}
        poi_dict['source']= site_root
        poi = PointsOfInterest(**poi_dict )

#         # define style -- no style for Archidont buildings
#         style=ArchitecturalStyles(style=row['Style'])
#         poi.styles.append(style)
        
        # architects (can be multiple)
        if pd.isnull(row['Architects:']) == False:
            prev_company=""
            #split multiple architects on \r\n
            for company in row['Architects:'].split('\r\n'):
                if company != prev_company:
                    architect = Architects(architect_name= company.replace("'","''"))
                    poi.architects.append(architect)
                    prev_company=company
        session.add(poi)
        session.commit()

# %%
def cleanup_data(df):
    # TODO: check for duplcates before inserting
    
    # remove demolished buildings for now
    df = df[df['Demolished'].isnull()]
    
    # Append TORONTO, ON to all addresses
    df['Address:'] = df['Address:'] + ", Toronto ON"
    
    # some of the building names are missing -- if so, then delete the row since it's meaningless for us
    df = df[df['Name of Building:'].isnull()==False]
    
    for ix, row in df.iterrows():
        if row['Address:'][0] == '0':
            print(row['Name of Building:'], row['Address:'], row['Type of Building:'])
            
    # we have some odd categories of buildings here that we don't really want to include in our walks
    
#     # check for 0 Street type addresses -- see if can flesh out
#     df['Address:'].apply(lambda x: print(x) if x[0] == '0' else print("ok"))
#    #if a.address[0] == '0':

    return df

# %%
if rerun_webscrape:
    run_webscrape()
    bld_df = pd.DataFrame(buildings_list)
    bld_df.to_csv('../data/archidont_buildings_'+ str(round(time.time(),0)) + '.csv')
else:
    bld_df=pd.read_csv('../data/archidont_buildingsB_Z.csv',index_col=0)
    print(bld_df.shape)
    bld_df=cleanup_data(bld_df)
    print(bld_df.shape)
bld_df.head()
# Out:
# (2447, 7)
# Canadian Bank of Commerce 0 Danforth Avenue, Toronto ON Banks
# Banca Commerciale Italiana 0 St. Clair Avenue West, Toronto ON Banks
# Bank of Nova Scotia 0 St. Clair Avenue West, Toronto ON Banks
# Molson Plant 0 Fleet Street, Toronto ON Breweries
# Governor's Bridge 0 Belt Line (Ravine), Toronto ON Bridges
# Governor's Bridge 0 Bloor Street East, Toronto ON Bridges
# Rosedale Valley Bridge 0 Bloor Street East, Toronto ON Bridges
# Cherry Street (lift) Bridge 0 Cherry Street, Toronto ON Bridges
# Don Valley Bicycle Bridge 0 Don Valley Parkway, Toronto ON Bridges
# Gerrard Street Bridge 0 Gerrard Street East, Toronto ON Bridges
# Humber Pedestrian Cycle Brg 0 Harbourfront, Toronto ON Bridges
# Huntley Street Bridge 0 Huntley Street, Toronto ON Bridges
# John St. Pedestrian Bridge 0 John Street, Toronto ON Bridges
# Mimico Creek bridge 0 Mimico Creek, Toronto ON Bridges
# Mount Pleasant Cemetery Bdg 0 Mount Pleasant Road, Toronto ON Bridges
# Queen Street Bridge 0 Queen Street East, Toronto ON Bridges
# St. Clair Avenue Bridge 0 St. Clair Avenue East, Toronto ON Bridges
# Wallace Avenue Footbridge 0 Wallace Avenue, Toronto ON Bridges
# Weston Road Bridge 0 Weston Road, Toronto ON Bridges
# Union Station Go Bus Terminal 0 Bay Street, Toronto ON Bus Terminals
# Scadding Cabin 0 Exhibition Place, Toronto ON Cabins
# University of Toronto Campus 0 University of Toronto, Toronto ON Campuses
# Elm Bank Cemetery 0 Fifth Line Road, Toronto ON Cemeteries
# Mount Pleasant Cemetery 0 Mount Pleasant Cemetery, Toronto ON Cemeteries
# Old Garrison Burying Ground 0 Wellington Street West, Toronto ON Cemeteries
# Potter's Field 0 Yonge Street, Toronto ON Cemeteries
# St. John's Cemetery Chapel 0 Kingston Road, Toronto ON Chapels
# Prospect Park United Church 0 Caledonia Road, Toronto ON Churches
# St. Patrick's Church 0 Dummer Street, Toronto ON Churches
# Canadian Coptic Centre 0 Eglinton Avenue West, Toronto ON Churches
# Gould St. United Presb. Church 0 Gould Street, Toronto ON Churches
# Annette Street Baptist Church 0 High Park Avenue, Toronto ON Churches
# St. Simon's Anglican Church 0 Howard Street, Toronto ON Churches
# St. Alban's Cathedral 0 Howland Avenue, Toronto ON Churches
# Unitarian Church 0 Jarvis Street, Toronto ON Churches
# Oriole Church 0 Leslie Street, Toronto ON Churches
# St. Cecilia's Roman Catholic Church 0 Pacific Avenue, Toronto ON Churches
# South Side Presbyterian Church 0 Parliament Street, Toronto ON Churches
# Knox's Presbyterian Church 0 Queen Street West, Toronto ON Churches
# Reid Avenue Baptist Church 0 Reid Avenue (no longer?), Toronto ON Churches
# Erskine United Church 0 Roncesvalles Avenue, Toronto ON Churches
# Erskine Presbyterian Church 0 Simcoe Street, Toronto ON Churches
# St. John's Anglican Church no1 0 St. John's Road, Toronto ON Churches
# St. Andrew's-by-the-Lake 0 Toronto Island(s), Toronto ON Churches
# Bay Street 0 Bay Street, Toronto ON City Blocks
# Bellevue Avenue 0 Bellevue Avenue, Toronto ON City Blocks
# Bond Street 0 Bond Street, Toronto ON City Blocks
# Dundas Square 0 Dundas Street East, Toronto ON City Blocks
# St. George Street 0 St. George Street, Toronto ON City Blocks
# Federal Avenue 0 University Avenue, Toronto ON City Blocks
# CityPlace 0 Waterfront Area, Toronto ON City Blocks
# Mississauga Civic Centre 0 Burnhamthorpe Rd., Toronto ON City Halls
# Para-Dice Riders Motorcycle Club 0 Eastern Avenue, Toronto ON Clubhouses
# Willard Hall 0 Gerrard Street East, Toronto ON Clubhouses
# Vagabonds' Clubhouse 0 Gerrard Street East, Toronto ON Clubhouses
# Satan's Choice Headquarters 0 Kintyre Avenue, Toronto ON Clubhouses
# Victoria Hall 0 Queen Street East, Toronto ON Clubhouses
# Royal Canadian Yacht Club 0 Toronto Island(s), Toronto ON Clubhouses
# Rochdale College 0 Huron Street, Toronto ON Colleges
# Centennial College (Morningside) 0 Morningside Avenue, Toronto ON Colleges
# Toronto School of Medicine 0 Sackville Street, Toronto ON Colleges
# Temple of Convenience 0 Toronto Street, Toronto ON Comfort Stations
# Hinder Park Pavilion 0 Bathurst Street, Toronto ON Community Centres
# Greek Community Centre 0 Canadian Road, Toronto ON Community Centres
# Harbourfront Community Ctr. 0 Harbourfront, Toronto ON Community Centres
# Stanley Community Centre 0 Stanley Road, Toronto ON Community Centres
# YMCA 0 Yonge Street, Toronto ON Community Centres
# Opera House (proposed) 0 Queen Street West, Toronto ON Concert Halls
# New York Towers 0 Bayview Avenue, Toronto ON Condominiums
# Bedford Glen 0 Bedford Park Avenue, Toronto ON Condominiums
# Bloorwest Lofts 0 Bloor Street West, Toronto ON Condominiums
# Modern on the Park 0 Bloor Street West, Toronto ON Condominiums
# St. James Condominiums (proposed) 0 Church Street, Toronto ON Condominiums
# Lofts (The) 0 Colborne Street, Toronto ON Condominiums
# Ideal Condominiums 0 College Street, Toronto ON Condominiums
# Residence of College Park 0 College Street, Toronto ON Condominiums
# Castle Hill 0 Davenport Road, Toronto ON Condominiums
# Excellence 0 Don Mills Road, Toronto ON Condominiums
# Grenadier Condominiums 0 Ellis Park Road, Toronto ON Condominiums
# Apex 0 Front Street East, Toronto ON Condominiums
# Matrix 0 Front Street East, Toronto ON Condominiums
# Camelot on the Ravine 0 Greenbelt Drive, Toronto ON Condominiums
# Radio City 0 Jarvis Street, Toronto ON Condominiums
# Massey Estates 0 Jarvis Street, Toronto ON Condominiums
# MoZo 0 King Street East, Toronto ON Condominiums
# Massey Square 0 King Street West, Toronto ON Condominiums
# French Quarter 0 Lombard Street, Toronto ON Condominiums
# Aqua 0 Queens Quay West, Toronto ON Condominiums
# Atrium on Queen's Quay 0 Queens Quay West, Toronto ON Condominiums
# Riviera 0 Queens Quay West, Toronto ON Condominiums
# World Trade Centre 0 Queens Quay West, Toronto ON Condominiums
# Richmond (the) 0 Richmond Street East, Toronto ON Condominiums
# Qwest 0 Richmond Street West, Toronto ON Condominiums
# Ideal Lofts 0 Richmond Street West, Toronto ON Condominiums
# University Plaza 0 Richmond Street West, Toronto ON Condominiums
# Governor's Bridge Estates 0 Rosedale Neighbourhood, Toronto ON Condominiums
# St. George on Sheldrake 0 Sheldrake Avenue, Toronto ON Condominiums
# Morgan (the) 0 Spadina Avenue, Toronto ON Condominiums
# Hudson (the) 0 Spadina Avenue, Toronto ON Condominiums
# Waterparkcity 0 Waterfront Area, Toronto ON Condominiums
# Waterclub Condominiums 0 Waterfront Area, Toronto ON Condominiums
# Javex Company Limited 0 Vanderhoof Avenue, Toronto ON Corporate Headquarters
# Wellesley Cottages 0 Wellesley Cottages, Toronto ON Cottages
# Robert Simpson Store 0 Dufferin Street, Toronto ON Department Stores
# New College Residence 0 Spadina Avenue, Toronto ON Dormitories
# Annette Street Public School 0 Annette Street, Toronto ON Elementary Schools
# Waterfront School 0 Bathurst Street, Toronto ON Elementary Schools
# Palace School 0 Cherry Street, Toronto ON Elementary Schools
# Eglinton Public School 0 Eglinton Avenue East, Toronto ON Elementary Schools
# Louisa Street School 0 Louisa Street, Toronto ON Elementary Schools
# Orde Street School 0 Orde, Toronto ON Elementary Schools
# Park Street School 0 Park Street, Toronto ON Elementary Schools
# No.22 York School 0 Runnymead Road, Toronto ON Elementary Schools
# Toronto Island School 0 Toronto Island(s), Toronto ON Elementary Schools
# Victoria Park Forst School 0 Victoria Park Avenue, Toronto ON Elementary Schools
# Metropolis 0 Dundas Street East, Toronto ON Entertainment Buildings
# Liberty Grand 0 Exhibition Place, Toronto ON Entertainment Buildings
# Metronome 0 Bathurst Quay, Toronto ON Exhibition Buildings
# Manufacturers & Industrial Art 0 Exhibition Place, Toronto ON Exhibition Buildings
# Food Products Building 0 Exhibition Place, Toronto ON Exhibition Buildings
# Music Building 0 Exhibition Place, Toronto ON Exhibition Buildings
# Ontario Government Building 0 Exhibition Place, Toronto ON Exhibition Buildings
# Better Living Centre 0 Exhibition Place, Toronto ON Exhibition Buildings
# National Trade Centre 0 Exhibition Place, Toronto ON Exhibition Buildings
# Horticultural Building 0 Exhibition Place, Toronto ON Exhibition Buildings
# Coliseum 0 Exhibition Place, Toronto ON Exhibition Buildings
# Automotive Building 0 Exhibition Place, Toronto ON Exhibition Buildings
# Arts and Crafts Buildings 0 Exhibition Place, Toronto ON Exhibition Buildings
# Circular Exhibition House 0 Exhibition Place, Toronto ON Exhibition Buildings
# Food Building 0 Exhibition Place, Toronto ON Exhibition Buildings
# Queen Elizabeth Building 0 Exhibition Place, Toronto ON Exhibition Buildings
# Ford Motor Co. of Canada Ltd. 0 Christie Street, Toronto ON Factories
# Davenport Works 0 Davenport Road, Toronto ON Factories
# Canadian Aeroplanes Ltd. 0 Dufferin Street, Toronto ON Factories
# McMurtry Furniture Factory 0 Dupont Street, Toronto ON Factories
# Canada Wire & Cable Co. 0 Laird Avenue, Toronto ON Factories
# Goodyear Plant 0 Lake Shore Boulevard West, Toronto ON Factories
# American Standard Factory 0 Lansdowne Avenue, Toronto ON Factories
# Watt Milling Co. 0 Osler Street, Toronto ON Factories
# Smith Brothers 0 Parliament Street, Toronto ON Factories
# Goodyear Tire & Rubber Co. 0 Richmond Street West, Toronto ON Factories
# General Steel Wares Plant 0 River Street, Toronto ON Factories
# Malthouse 0 River Street, Toronto ON Factories
# Cowan Cocoa & Chocolate Works 0 Stirling Street, Toronto ON Factories
# British Forgings Melting House 0 Waterfront Area, Toronto ON Factories
# Shoot City Complex 0 Cherry Street, Toronto ON Film Studios
# Music Garden 0 Queens Quay West, Toronto ON Gardens
# Consumers Gas Company 0 Parliament Street, Toronto ON Gasworks
# Claxton Blvd. Street Gate 0 Claxton Boulevard, Toronto ON Gates
# China Gate 0 Gerrard Street East, Toronto ON Gates
# North York Municipal Bldg. 0 Beecroft Road, Toronto ON Government Office Buildings
# Canada Malting 0 Bathurst Quay, Toronto ON Grain Elevators
# Dempsey's Hardware Store 0 Beecroft Road, Toronto ON Hardware Stores
# Toronto Collegiate Institute 0 Jarvis Street, Toronto ON High Schools
# Dr. Meyers' Private Hospital... 0 Heath Street West, Toronto ON Hospitals
# Evangelical Settlement 0 Queen Street East, Toronto ON Hospitals
# Infants Home 0 Sackville Street, Toronto ON Hostels
# Ritz-Carlon Hotel / Condos 0 Bay Street, Toronto ON Hotels
# Garibaldi House 0 Berkeley Street, Toronto ON Hotels
# Soho Metropolitan 0 Blue Jays Way, Toronto ON Hotels
# Walker House 0 Front Street West, Toronto ON Hotels
# Sword's Hotel 0 Front Street West, Toronto ON Hotels
# Germain Hotel 0 Mercer Street, Toronto ON Hotels
# Rupert Hotel 0 Queen Street East, Toronto ON Hotels
# Hotel Hanlan 0 Toronto Island(s), Toronto ON Hotels
# Soho Grand Hotel and Condos 0 Wellington Street West, Toronto ON Hotels
# Pantages Tower 0 Yonge Street, Toronto ON Hotels
# Clover Hill 0 Bay Street, Toronto ON Houses
# Elmsley Villa 0 Bay Street, Toronto ON Houses
# Pinehurst 0 Beverley Street, Toronto ON Houses
# Joseph Shepard House 0 Burndale Avenue, Toronto ON Houses
# Victory House 0 Cochrane Drive, Toronto ON Houses
# Colborne Lodge 0 Colborne Lodge Drive, Toronto ON Houses
# William Hume Blake House 0 Davenport Road, Toronto ON Houses
# Wychwood 0 Davenport Road, Toronto ON Houses
# Deer Park 0 Deer Park Neighbourhood, Toronto ON Houses
# William Pears Residence 0 Evelyn Crescent, Toronto ON Houses
# Shadowbrooke 0 Finch Avenue West, Toronto ON Houses
# Donald Stephenson House 0 Gerrard Street East, Toronto ON Houses
# Clandeboye 0 Gothic Avenue, Toronto ON Houses
# Jane Parker Square 0 Laughton Avenue, Toronto ON Houses
# Huntly Lodge 0 Lawton Boulevard, Toronto ON Houses
# Kingsland 0 Lympstone Avenue, Toronto ON Houses
# Howard Estate 0 Maclean Avenue, Toronto ON Houses
# Patio Homes 0 Mainroyal Street, Toronto ON Houses
# Valley Halla 0 Meadowvale Road, Toronto ON Houses
# Willowbank 0 Oriole Parkway, Toronto ON Houses
# Petersfield 0 Queen Street West, Toronto ON Houses
# Brookfield 0 Queen Street West, Toronto ON Houses
# Rathnelly 0 Rathnelly Avenue, Toronto ON Houses
# Runnymead 0 Scarlett Road, Toronto ON Houses
# Roselands 0 Seaton Street, Toronto ON Houses
# Moss Park (William Allan Estate) 0 Sherbourne Street, Toronto ON Houses
# Sunlands 0 Summit Drive, Toronto ON Houses
# Victory House 0 Uno Drive, Toronto ON Houses
# Robert Baldwin Sullivan House 0 Yonge Street, Toronto ON Houses
# Chestnut Park (house) 0 Yonge Street, Toronto ON Houses
# Alexandra Park Phase II 0 Cameron Street, Toronto ON Housing
# Tent City 0 Cherry Street, Toronto ON Housing
# St. Clarens Village 0 Davenport Road, Toronto ON Housing
# Parkway Forest 0 Don Mills Road, Toronto ON Housing
# Don Mount Court 0 Dundas Street East, Toronto ON Housing
# Scadding Court 0 Dundas Street West, Toronto ON Housing
# Alexandra Park - Phase I 0 Dundas Street West, Toronto ON Housing
# Regent Park North 0 Gerrard Street East, Toronto ON Housing
# Beverly Place 0 Henry Street, Toronto ON Housing
# Yorkwoods Village 0 Jane Street, Toronto ON Housing
# Robert J. Smith Apartments 0 Kipling Avenue, Toronto ON Housing
# Pembroke Sherbourne Housing 0 Pembroke Street, Toronto ON Housing
# Moss Park Apartments 0 Queen Street East, Toronto ON Housing
# Wycliffe Hill 0 Shaughnessy Boulevard, Toronto ON Housing
# Sherbourne Lanes 0 Sherbourne Street, Toronto ON Housing
# Regent Park South 0 Shuter Street, Toronto ON Housing
# Maybank Housing Project 0 Weston Road, Toronto ON Housing
# Parkhurst Station 0 Parkhurst Boulevard, Toronto ON Hydro-Electric Stations
# Provincial Parliament Buildings - East Block 0 Queen's Park Crescent E., Toronto ON Legislative Buildings
# Lighthouse 0 Toronto Island(s), Toronto ON Lighthouses
# Princes' Gates 0 Exhibition Place, Toronto ON Memorial Arches
# Margaret Fairley Memorial 0 Brunswick Avenue, Toronto ON Memorials
# Sir Casimir Gzowski Memorial 0 Lake Shore Boulevard West, Toronto ON Memorials
# Ned Hanlan memorial 0 Lake Shore Boulevard West, Toronto ON Memorials
# William Thomas Monument 0 Mount Pleasant Cemetery, Toronto ON Memorials
# War of 1812 Memorial 0 Portland Street, Toronto ON Memorials
# Forty-Eighth Highlanders Regimental Memorial 0 Queen's Park, Toronto ON Memorials
# Katyn Memorial 0 Roncesvalles Avenue, Toronto ON Memorials
# Canadian Airmens' Memorial 0 University Avenue, Toronto ON Memorials
# Adam Beck Memorial 0 University Avenue, Toronto ON Memorials
# South African War Memorial 0 University Avenue, Toronto ON Memorials
# Deer Park Sanatorium 0 Heath Street West, Toronto ON Mental Health Facilities
# Lakeshore Psychiatric Hospital 0 Lake Shore Boulevard West, Toronto ON Mental Health Facilities
# Marine Museum 0 Exhibition Place, Toronto ON Museums
# Annex Neighbourhood 0 Annex Neighbourhood, Toronto ON Neighbourhoods
# Aratiri Neighbourhood 0 Bayview Avenue, Toronto ON Neighbourhoods
# Bennington Heights Nghbd 0 Bennington Heights Nghbd, Toronto ON Neighbourhoods
# Bridle Path Neighbourhood 0 Bridle Path Neighbourhood, Toronto ON Neighbourhoods
# Long Branch Neighbourhood 0 Browns Line, Toronto ON Neighbourhoods
# Cabbagetown Neighbourhood 0 Cabbagetown Neighbourhood, Toronto ON Neighbourhoods
# Church / Wellesley Neighbourhd 0 Church Street, Toronto ON Neighbourhoods
# Deer Park Neighbourhood 0 Deer Park Neighbourhood, Toronto ON Neighbourhoods
# Don Mills Neighbourhood 0 Don Mills Neighbourhood, Toronto ON Neighbourhoods
# Financial District Neighbourhood 0 Financial District, Toronto ON Neighbourhoods
# Forest Hill Neighbourhood 0 Forest Hill Neighbourhood, Toronto ON Neighbourhoods
# Humber Valley Village 0 Humber Valley Village, Toronto ON Neighbourhoods
# Junction District 0 Junction District, Toronto ON Neighbourhoods
# Industrial Area 0 King Street East, Toronto ON Neighbourhoods
# Industrial Area 0 King Street West, Toronto ON Neighbourhoods
# Liberty Village 0 King Street West, Toronto ON Neighbourhoods
# Kingsway Neighbourhood 0 Kingsway Neighbourhood, Toronto ON Neighbourhoods
# Leaside Neighbourhood 0 Leaside Neighbourhood, Toronto ON Neighbourhoods
# Mount Dennis Neighbourhood 0 Mount Dennis Neihgbourhd, Toronto ON Neighbourhoods
# Old Town Neighbourhood 0 Old Town Neighbourhood, Toronto ON Neighbourhoods
# Parkdale Neighbourhood 0 Parkdale Neighbourhood, Toronto ON Neighbourhoods
# Beach Project 0 Queen Street East, Toronto ON Neighbourhoods
# Riverdale Neighbourhood 0 Riverdale Neighbourhood, Toronto ON Neighbourhoods
# Rosedale Neighbourhood 0 Rosedale Neighbourhood, Toronto ON Neighbourhoods
# Chinatown 0 Spadina Avenue, Toronto ON Neighbourhoods
# St. Lawrence Neighbourhood 0 St. Lawrence Neighbourhd., Toronto ON Neighbourhoods
# C-2 Block 0 St. Lawrence Neighbourhd., Toronto ON Neighbourhoods
# Swansea Neighbourhood 0 Swansea Neighbourhood, Toronto ON Neighbourhoods
# Thorncliffe Park Neighbourhood 0 Thorncliffe Park Neighbhd, Toronto ON Neighbourhoods
# Wychwood Park Neighbourhood 0 Wychwood Park Neighbourhd, Toronto ON Neighbourhoods
# Northtown 0 Yonge Street, Toronto ON Neighbourhoods
# Yonge & St. Clair Intersection 0 Yonge Street, Toronto ON Neighbourhoods
# Freehold Loan and Savings Co. 0 Adelaide Street East, Toronto ON Office Buildings
# Ontario Medical Council Bldg. 0 Bay Street, Toronto ON Office Buildings
# Northern Railway of Canada 0 Front Street West, Toronto ON Office Buildings
# iT-works 0 Gardiner Expressway, Toronto ON Office Buildings
# Canada Life Assurance Co. 0 King Street West, Toronto ON Office Buildings
# Canada Life Assurance Bldg. 0 King Street West, Toronto ON Office Buildings
# Cobban Manufacturing Co. 0 Lake Street (not current), Toronto ON Office Buildings
# Royal Bank Centre 0 Mississauga Road North, Toronto ON Office Buildings
# Canadian Institute Building 0 Pembroke Street, Toronto ON Office Buildings
# International Woodworkers of America 0 Weston Road, Toronto ON Office Buildings
# Bay-Adelaide Centre 0 Bay Street, Toronto ON Office Towers
# Canada Life Tower 0 Queen Street West, Toronto ON Office Towers
# Vaughan Buildings 0 Steeles Avenue, Toronto ON Office Towers
# Chorley Park 0 Roxborough Drive, Toronto ON Official Residences
# Parking Authority of Tor no.42 0 Dufferin Street, Toronto ON Parking Garages
# Toronto Parking Authority 0 Dundas Square, Toronto ON Parking Garages
# Charles Hayden Parking Garage 0 Hayden Street, Toronto ON Parking Garages
# Albany Parkette 0 Bathurst Street, Toronto ON Parks
# Bay Adelaide Park 0 Bay Street, Toronto ON Parks
# Balmy Beach Park 0 Beech Avenue, Toronto ON Parks
# Matt Cohen Park 0 Bloor Street West, Toronto ON Parks
# Roundhouse Park 0 Bremner Boulevard, Toronto ON Parks
# Riverdale Park 0 Broadview Avenue, Toronto ON Parks
# Cumberland Park 0 Cumberland Street, Toronto ON Parks
# Dufferin Grove Park 0 Dufferin Street, Toronto ON Parks
# Berczy Park 0 Front Street East, Toronto ON Parks
# Simcoe Place Park 0 Front Street West, Toronto ON Parks
# Grange Park 0 Grange Road, Toronto ON Parks
# Norman Jewison Park 0 Isabella Street, Toronto ON Parks
# Park at First Canadian Place 0 King Street West, Toronto ON Parks
# Small's Park / Pond 0 Kingston Road, Toronto ON Parks
# Greenwood Park 0 Lake Shore Boulevard East, Toronto ON Parks
# Edwards Gardens 0 Lawrence Avenue East, Toronto ON Parks
# Kew Gardens 0 Queen Street East, Toronto ON Parks
# Trinity Bellwoods Park 0 Queen Street West, Toronto ON Parks
# David A. Balfour Park 0 Rosehill Avenue, Toronto ON Parks
# Rouge Park 0 Rouge Park, Toronto ON Parks
# Downsview Park 0 Sheppard Avenue, Toronto ON Parks
# Tree City 0 Sheppard Avenue, Toronto ON Parks
# Allan Gardens 0 Sherbourne Street, Toronto ON Parks
# Moss Park (Park) 0 Sherbourne Street, Toronto ON Parks
# Government House Pleasure Ground 0 Simcoe Street, Toronto ON Parks
# Crescent Gardens
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#  0 Spadina Avenue, Toronto ON Parks
# Penninsula Pleasure Ground 0 Toronto Island(s), Toronto ON Parks
# Victoria Park 0 Victoria Park Avenue, Toronto ON Parks
# Alexander Muir Memorial Gardens 0 Yonge Street, Toronto ON Parks
# High Park Pavilion 0 High Park, Toronto ON Pavilions
# Coronation Park Pavilion 0 Lake Shore Boulevard West, Toronto ON Pavilions
# Allan Gardens Pavilion no.3 0 Sherbourne Street, Toronto ON Pavilions
# Toronto Arts Building 0 Victoria Street, Toronto ON Performing Arts Centres
# Ryerson Athletic Facilities 0 Gerrard Street East, Toronto ON Physical Education Buildings
# Mail Building 0 King Street West, Toronto ON Post Offices
# Nortwind Toronto District Cooling Project 0 Front Street West, Toronto ON Power Plants
# Lakeview Generating Station 0 Lake Shore Boulevard West, Toronto ON Power Plants
# Bishop Strachan School 0 College Street, Toronto ON Private Schools
# Upper Canada College 0 King Street West, Toronto ON Private Schools
# Peter Pan Statue 0 Avenue Road, Toronto ON Public Sculpture
# Sibelius Monument 0 Brunswick Avenue, Toronto ON Public Sculpture
# Elevated Wetlands 0 Don Valley Parkway, Toronto ON Public Sculpture
# Three Dark Figures 0 Dufferin Street, Toronto ON Public Sculpture
# Berczy Family Sculpture 0 Front Street East, Toronto ON Public Sculpture
# "Untitled" 0 Front Street West, Toronto ON Public Sculpture
# "Campsite Founding" 0 Front Street West, Toronto ON Public Sculpture
# Larry Sefton Memorial 0 Hagerman Street, Toronto ON Public Sculpture
# Halo 0 Harbourfront, Toronto ON Public Sculpture
# Lion Monument 0 Lake Shore Boulevard West, Toronto ON Public Sculpture
# C.W. Jefferys Statue 0 Mill Street (North York), Toronto ON Public Sculpture
# "TIME: And a Clock" 0 Queen Street East, Toronto ON Public Sculpture
# Simon Bolivar Statue 0 Queen Street West, Toronto ON Public Sculpture
# Sir John A. MacDonald 0 Queen's Park, Toronto ON Public Sculpture
# Queen Victoria Monument 0 Queen's Park, Toronto ON Public Sculpture
# North-West Rebellion Memorial 0 Queen's Park, Toronto ON Public Sculpture
# General John Graves Simcoe Memorial 0 Queen's Park, Toronto ON Public Sculpture
# John Sandfield Macdonald 0 Queen's Park, Toronto ON Public Sculpture
# Sir James Pliny Whitney 0 Queen's Park, Toronto ON Public Sculpture
# George Brown 0 Queen's Park, Toronto ON Public Sculpture
# Sir Oliver Mowat 0 Queen's Park, Toronto ON Public Sculpture
# William Lyon Mackenzie 0 Queen's Park, Toronto ON Public Sculpture
# Edward VII Equestrain Statue 0 Queen's Park, Toronto ON Public Sculpture
# Canadian Volunteer Monument (Fenian Raid) 0 Queen's Park Crescent W., Toronto ON Public Sculpture
# Robert Raikes 0 Queen's Park Crescent W., Toronto ON Public Sculpture
# Learn to Throw Your Voice 0 Queens Quay West, Toronto ON Public Sculpture
# Robert Burns Monument 0 Sherbourne Street, Toronto ON Public Sculpture
# "Spadina Line" 0 Spadina Avenue, Toronto ON Public Sculpture
# Florence Wyle Sculpture 0 St. Clair Avenue East, Toronto ON Public Sculpture
# Frances Loring Sculpture 0 St. Clair Avenue East, Toronto ON Public Sculpture
# "Sun Life" 0 University Avenue, Toronto ON Public Sculpture
# Robert H. Saunders Monument 0 University Avenue, Toronto ON Public Sculpture
# John Street Roundhouse 0 Bremner Boulevard, Toronto ON Railway Buildings
# CPR West Toronto Roundhouse 0 Dodds Avenue, Toronto ON Railway Buildings
# Riverdale Train Station 0 DeGrassi Street, Toronto ON Railway Stations
# Moore Park Station 0 Moore Avenue, Toronto ON Railway Stations
# Belt Line Railway 0 Mount Pleasant Cemetery, Toronto ON Railways
# Ryerson Centre for Computing & Engineering 0 Church Street, Toronto ON Research Buildings
# Connaught Laboratories 0 Dufferin Street, Toronto ON Research Buildings
# Pharmacy Building 0 Queen's Park Crescent W., Toronto ON Research Buildings
# Bahen Centre for IT 0 St. George Street, Toronto ON Research Buildings
# Canary Restaurant 0 Cherry Street, Toronto ON Restaurants
# Southill Row Houses 0 Don Mills Neighbourhood, Toronto ON Row Houses
# Don Valley Village 0 Don Mills Neighbourhood, Toronto ON Row Houses
# Yorkwoods Village 0 London Green Court, Toronto ON Row Houses
# Bridlemanor Townhouses 0 Pharmacy Avenue, Toronto ON Row Houses
# Massey Square 0 Shank Street, Toronto ON Row Houses
# Citadel Village 0 Valley Woods Drive, Toronto ON Row Houses
# Yorkdale Shopping Centre 0 Dufferin Street, Toronto ON Shopping Complexes
# Roys Square Mews 0 Yonge Street, Toronto ON Shopping Complexes
# York Mills Shopping Centre 0 York Mills Road, Toronto ON Shopping Complexes
# York Square 0 Yorkville Avenue, Toronto ON Shopping Complexes
# Browns Line Square 0 Browns Line, Toronto ON Squares
# Confederation Square 0 Yonge Street, Toronto ON Squares
# Maple Leaf Stadium 0 Bathurst Street, Toronto ON Stadiums
# Exhibition Stadium 0 Exhibition Place, Toronto ON Stadiums
# Coronation Park 0 Lake Shore Boulevard West, Toronto ON Stadiums
# Binscarth Road 0 Binscarth Road, Toronto ON Streetlights
# Alfresco Lawn 0 Alfresco Lawn, Toronto ON Streets
# Baby Point Road 0 Baby Point Road, Toronto ON Streets
# Barber Avenue 0 Bartlett Avenue, Toronto ON Streets
# Bloor Street West 0 Bloor Street West, Toronto ON Streets
# Bremner Boulevard 0 Bremner Boulevard, Toronto ON Streets
# Charles Street West 0 Charles Street East, Toronto ON Streets
# Cherry Street 0 Cherry Street, Toronto ON Streets
# College Street 0 College Street, Toronto ON Streets
# Coxwell Avenue 0 Coxwell Avenue, Toronto ON Streets
# Danforth Avenue 0 Danforth Avenue, Toronto ON Streets
# Dowling Avenue 0 Dowling Avenue., Toronto ON Streets
# Draper Street 0 Draper Street, Toronto ON Streets
# Duncan Street 0 Duncan Street, Toronto ON Streets
# Edward Street 0 Edward Street, Toronto ON Streets
# Grace Street 0 Grandravine Drive, Toronto ON Streets
# Grenview Boulevard 0 Grenview Boulevard, Toronto ON Streets
# Jackson Avenue 0 Jackson Avenue, Toronto ON Streets
# Jarvis Street 0 Jarvis Street, Toronto ON Streets
# Kendal Avenue 0 Kendal Avenue, Toronto ON Streets
# King's Garden Boulevard 0 King's Garden Boulevard, Toronto ON Streets
# Kings Lynn Road 0 Kings Lynn Road, Toronto ON Streets
# Kingscourt Drive 0 Kingscourt Drive, Toronto ON Streets
# Kingsmill Road 0 Kingsmill Road, Toronto ON Streets
# Montrose Avenue 0 Montrose Avenue, Toronto ON Streets
# Prince Edward Drive 0 Prince Edward Drive, Toronto ON Streets
# Queens Quay West 0 Queens Quay West, Toronto ON Streets
# Reid Avenue 0 Reid Avenue (no longer?), Toronto ON Streets
# Roncesvalles Avenue 0 Roncesvalles Avenue, Toronto ON Streets
# Royal York Road 0 Royal York Road, Toronto ON Streets
# Scollard Street 0 Scollard Street, Toronto ON Streets
# Simpson Avenue 0 Simpson Avenue, Toronto ON Streets
# Spadina Avenue 0 Spadina Avenue, Toronto ON Streets
# University Avenue 0 University Avenue, Toronto ON Streets
# Wendover Road 0 Wendover Road, Toronto ON Streets
# Westholme Avenue 0 Westholme Avenue, Toronto ON Streets
# Willingdon Boulevard 0 Willingdon Boulevard, Toronto ON Streets
# Woodlawn Avenue 0 Woodlawn Avenue West, Toronto ON Streets
# Yonge Street 0 Yonge Street, Toronto ON Streets
# Yonge & Bloor Intersection 0 Yonge Street, Toronto ON Streets
# Parkway East 0 Don Mills Neighbourhood, Toronto ON Suburbs
# Lawrence Park Neighbourhood 0 Lawrence Park Neighbourhd, Toronto ON Suburbs
# Morningside Heights 0 Steeles Avenue East, Toronto ON Suburbs
# Sheppard Subway System 0 Sheppard Avenue, Toronto ON Subway Stations
# Spadina Subway Station 0 Spadina Subway Line, Toronto ON Subway Stations
# Dupont Subway Station 0 Spadina Subway Line, Toronto ON Subway Stations
# St. Clair Subway Station 0 Spadina Subway Line, Toronto ON Subway Stations
# Eglinton Subway Station 0 Spadina Subway Line, Toronto ON Subway Stations
# Glencairn Subway Station 0 Spadina Subway Line, Toronto ON Subway Stations
# Lawrence Subway Station 0 Spadina Subway Line, Toronto ON Subway Stations
# Yorkdale Subway Station 0 Spadina Subway Line, Toronto ON Subway Stations
# Wilson Subway Station 0 Spadina Subway Line, Toronto ON Subway Stations
# Sunnyside Bathing Pavilion 0 Sunnyside Beach, Toronto ON Swimming Pools
# Beth Jacob Synagogue 0 Henry Street, Toronto ON Synagogues
# Craig & Wickett Tannery 0 Cypress Street, Toronto ON Tanneries
# Green Bush Inn 0 Steeles Avenue, Toronto ON Taverns
# Colossos 0 Highway 400, Toronto ON Theatres
# Oakwood Theatre 0 Oakwood Avenue, Toronto ON Theatres
# Festival Hall 0 Richmond Street West, Toronto ON Theatres
# Shea's Victoria Theatre 0 Victoria Street, Toronto ON Theatres
# AT & T Centre for the Perf. Ar 0 Yonge Street, Toronto ON Theatres
# Silver City 0 Yonge Street, Toronto ON Theatres
# Bulova Tower 0 Exhibition Place, Toronto ON Towers
# Media Tower 0 Yonge Street, Toronto ON Towers
# Estate of mind 0 Alcina Avenue, Toronto ON Town Houses
# Town Manors of Glenforest 0 Glenforest Road, Toronto ON Town Houses
# Park Place 0 Maitland Street, Toronto ON Town Houses
# Massey Common 0 Massey Street, Toronto ON Town Houses
# Mitchell Avenue Mews 0 Mitchell Avenue, Toronto ON Town Houses
# Morningside Villas 0 Morningside Avenue, Toronto ON Town Houses
# Upper East Side 0 Pape Avenue, Toronto ON Town Houses
# Castle View 0 Spadina Road, Toronto ON Town Houses
# Bay / Wellington Project 0 Bay Street, Toronto ON UNKNOWN
# Hanlan's Point 0 Hanlan's Point, Toronto ON UNKNOWN
# Grenadier Pond 0 High Park, Toronto ON UNKNOWN
# Bloor Street Viaduct 0 Bloor Street East, Toronto ON Viaducts
# PATH 0 Bay Street, Toronto ON Walkways
# Boardwalk 0 Beaches Area, Toronto ON Walkways
# Canadian Pacific Express Bldg. 0 King Street West, Toronto ON Warehouses
# Harbourfront 2000 0 Harbourfront, Toronto ON Waterfronts
# Harbourfront 0 Harbourfront, Toronto ON Waterfronts
# Waterfront Park 0 Harbourfront, Toronto ON Waterfronts
# Waterfront Area 0 Waterfront Area, Toronto ON Waterfronts
# Port Lands 0 Waterfront Area, Toronto ON Waterfronts
# Harry Piper's Wild Animal Zoo 0 Front Street West, Toronto ON Zoos
# Metropolitan Toronto Zoo 0 Meadowvale Road, Toronto ON Zoos
# (1654, 7)
#                              Address:                      Architects:  \
# 1        63 Walker Avenue, Toronto ON                              NaN
# 3   420 Bloor Street East, Toronto ON                        Lyle John
# 4   539 Bloor Street West, Toronto ON                   Horsburgh V.C.
# 5  1129 Bloor Street West, Toronto ON  Taylor Hazell Architects (firm)
# 6    363 Broadview Avenue, Toronto ON                        Lyle John
#
#   Building completed Demolished          Name of Building:  \
# 1                NaN        NaN              Hunt's Bakery
# 3               1911        NaN      Toronto Dominion Bank
# 4               1914        NaN  Canadian Bank of Commerce
# 5                NaN        NaN  Canadian Bank of Commerce
# 6               1911        NaN        Bank of Nova Scotia
#
#                                               Notes: Type of Building:
# 1  HUnt's Bakery operated here from 1928-1979.  S...          Bakeries
# 3                                                NaN             Banks
# 4                           Now houses Pauper's Pub.             Banks
# 5                                                NaN             Banks
# 6                                                NaN             Banks

# %%
#bld_df[bld_df['Demolished'].isnull() == False]
# 208 demolished buildings -- for our purpooses, probably no benefit in keepnig

# %%
bld_df['Type of Building:'].unique()
# Out:
# array(['Bakeries', 'Banks', 'Book Stores', 'Breweries', 'Bridges',
#        'Broadcasting Stations', 'Bus Terminals', 'Cabins', 'Campuses',
#        'Cemeteries', 'Chapels', 'Churches', 'City Blocks', 'City Halls',
#        'Clothing Stores', 'Clubhouses', 'Coach Houses', 'Colleges',
#        'Comfort Stations', 'Community Centres', 'Concert Halls',
#        'Condominiums', 'Convention Centres', 'Corporate Headquarters',
#        'Cottages', 'Courthouses', 'Cultural Centres', 'Dairies',
#        'Day Care Centres', 'Department Stores', 'Design Centres',
#        'Dormitories', 'Elementary Schools', 'Entertainment Buildings',
#        'Exhibition Buildings', 'Extended Care Facilities', 'Factories',
#        'Film Studios', 'Fire Stations', 'Gardens', 'Gasworks', 'Gates',
#        'Government Office Buildings', 'Grain Elevators', 'Greenhouses',
#        'Grocery Stores', 'Hardware Stores', 'High Schools', 'Hospitals',
#        'Hostels', 'Hotels', 'Houses', 'Housing',
#        'Hydro-Electric Stations', 'Jails', 'Legislative Buildings',
#        'Libraries', 'Lighthouses', 'Mansions', 'Markets',
#        'Memorial Arches', 'Memorials', 'Mental Health Facilities',
#        'Motels', 'Museums', 'Music Schools', 'Neighbourhoods',
#        'Nightclubs', 'Observatories', 'Office Buildings', 'Office Towers',
#        'Official Residences', 'Open-Air Theatres', 'Owner-built houses',
#        'Parking Garages', 'Parks', 'Parsonages', 'Pavilions',
#        'Performing Arts Centres', 'Physical Education Buildings',
#        'Police Stations', 'Polytechnics', 'Post Offices', 'Power Plants',
#        'Private Schools', 'Public Baths', 'Public Sculpture',
#        'Publishing Offices', 'Railway Buildings', 'Railway Stations',
#        'Railways', 'Research Buildings', 'Restaurants', 'Retail Stores',
#        'Row Houses', "Senior Citizens' Housing", 'Service Stations',
#        'Shopping Complexes', 'Squares', 'Stadiums', 'Stock Exchanges',
#        'Streetlights', 'Streets', 'Student Unions', 'Studios', 'Suburbs',
#        'Subway Stations', 'Supermarkets', 'Swimming Pools', 'Synagogues',
#        'Tanneries', 'Taverns', 'Telephone Exchanges', 'Theatres',
#        'Towers', 'Town Houses', 'Transmission Towers', 'UNKNOWN',
#        'Universities', 'Viaducts', 'Walkways', 'Warehouses',
#        'Waterfronts', 'Waterworks', 'Zoos'], dtype=object)

# %%
cats_to_drop = ['Subway Stations']
bld_df[bld_df['Type of Building:']=='Houses']
# Out:
#                                    Address:  \
# 893             15 Admiral Road, Toronto ON
# 897            41 Alcina Avenue, Toronto ON
# 907          288 Annette Street, Toronto ON
# 908          336 Annette Street, Toronto ON
# 915         125 Aspenwood Drive, Toronto ON
# 919              2 Ava Crescent, Toronto ON
# 922            34 Avondale Road, Toronto ON
# 925          200 Baldwin Avenue, Toronto ON
# 931                0 Bay Street, Toronto ON
# 932                0 Bay Street, Toronto ON
# 933         2075 Bayview Avenue, Toronto ON
# 934         2075 Bayview Avenue, Toronto ON
# 936         2275 Bayview Avenue, Toronto ON
# 938         2489 Bayview Avenue, Toronto ON
# 940             32 Beaty Avenue, Toronto ON
# 941      31 Bedford Park Avenue, Toronto ON
# 955         115 Berkeley Street, Toronto ON
# 958           0 Beverley Street, Toronto ON
# 959         130 Beverley Street, Toronto ON
# 961         152 Beverley Street, Toronto ON
# 962         186 Beverley Street, Toronto ON
# 974          102 Blythwood Road, Toronto ON
# 975          543 Blythwood Road, Toronto ON
# 976              82 Bond Street, Toronto ON
# 983        646 Broadview Avenue, Toronto ON
# 984        648 Broadview Avenue, Toronto ON
# 985        660 Broadview Avenue, Toronto ON
# 989            10 Buchan Street, Toronto ON
# 990           0 Burndale Avenue, Toronto ON
# 992           12 Bushbury Drive, Toronto ON
# ...                                     ...
# 1331            0 Scarlett Road, Toronto ON
# 1332            0 Seaton Street, Toronto ON
# 1337        0 Sherbourne Street, Toronto ON
# 1340      291 Sherbourne Street, Toronto ON
# 1349           285 Spadina Road, Toronto ON
# 1356       1 St. Edmund's Drive, Toronto ON
# 1357      35 St. Edmund's Drive, Toronto ON
# 1360       44 St. George Street, Toronto ON
# 1361       89 St. George Street, Toronto ON
# 1369     40 St. Leonards Avenue, Toronto ON
# 1372            1 Sumach Street, Toronto ON
# 1374          384 Sumach Street, Toronto ON
# 1376             0 Summit Drive, Toronto ON
# 1384      211 University Avenue, Toronto ON
# 1385                0 Uno Drive, Toronto ON
# 1388            29 Wales Avenue, Toronto ON
# 1396            109 Walmer Road, Toronto ON
# 1400            190 Warren Road, Toronto ON
# 1404   56 Wellesley Street East, Toronto ON
# 1409  402 Wellesley Street East, Toronto ON
# 1419      41 Weybourne Crescent, Toronto ON
# 1423       85 Winchester Street, Toronto ON
# 1433    35 Woodlawn Avenue West, Toronto ON
# 1435    63 Woodlawn Avenue West, Toronto ON
# 1436    67 Woodlawn Avenue West, Toronto ON
# 1439             0 Yonge Street, Toronto ON
# 1440             0 Yonge Street, Toronto ON
# 1443          4111 Yonge Street, Toronto ON
# 1444          5172 Yonge Street, Toronto ON
# 1447        77 Yorkville Avenue, Toronto ON
#
#                                             Architects: Building completed  \
# 893                                          Todd David               1891
# 897                                                 NaN                NaN
# 907                         Knox Elliot & Jarvis (firm)               1899
# 908                                                 NaN              c1910
# 915                                                 NaN             c1830s
# 919                                 Biriukova Alexandra                NaN
# 922                                                 NaN               1834
# 925   Marecheaux Otis\r\nPeacock Gregory\r\nWinton T...          1993-1994
# 931                                                 NaN               1829
# 932                                                 NaN              c1837
# 933                           Burden & Gouinlock (firm)               1931
# 934     Arthur Eric\r\nGeorge, Moorehouse & King (firm)               1931
# 936                     Molesworth West & Secord (firm)               1925
# 938                     Davidson Jocelyn\r\nMorgan Earl            1936-37
# 940                                                 NaN                NaN
# 941                                                 NaN              c1885
# 955                                                 NaN                NaN
# 958                                                 NaN                NaN
# 959                                                 NaN                NaN
# 961                              Sproatt & Rolph (firm)               1874
# 962                   Hutchins Edward\r\nIrving William               1877
# 974                                          Smith Eden                NaN
# 975                                      Rebanks Leslie                NaN
# 976                                                 NaN              c1858
# 983                                        Havill James               1908
# 984                                           Warren H.               1907
# 985                                    Gouinlock George          1908-1909
# 989                                                 NaN               1945
# 990                                                 NaN              c1835
# 992                              Wickson & Gregg (firm)               1919
# ...                                                 ...                ...
# 1331                                                NaN               1838
# 1332                                                NaN                NaN
# 1337                                        Howard John          1826-1830
# 1340                                                NaN            c1880s?
# 1349                                                NaN               1886
# 1356                         Chadwick & Beckett  (firm)              c1909
# 1357                         Chadwick & Beckett  (firm)              c1909
# 1360                                                NaN               1878
# 1361                                      Miller George              c1891
# 1369                         Chadwick & Beckett  (firm)              c1910
# 1372                                          Blom Piet                NaN
# 1374                                                NaN              c1866
# 1376                   George, Moorehouse & King (firm)             c1930s
# 1384                                                NaN                NaN
# 1385                                                NaN                NaN
# 1388                                                NaN               1884
# 1396                              Townsend. S. Hamilton               1904
# 1400                                         Smith Eden               1911
# 1404                                                NaN               1856
# 1409                                                NaN          1892-1893
# 1419                     Fleury Arthur & Calvert (firm)             c.1956
# 1423                                                NaN               1857
# 1433  Gregg & Gregg (firm)\r\nHoward John\r\nMundie ...              c1840
# 1435                                     Markson Jerome                NaN
# 1436                                                NaN                NaN
# 1439                                Cumberland Frederic                NaN
# 1440                          Cumberland & Storm (firm)                NaN
# 1443                                                NaN               1815
# 1444                                                NaN               1851
# 1447                                                NaN              c1867
#
#      Demolished                 Name of Building:  \
# 893         NaN                   15 Admiral Road
# 897         NaN                 York Wilson House
# 907         NaN                     Birches (The)
# 908         NaN                   Oaklands  (The)
# 915         NaN                 John Duncan House
# 919         NaN               Lawren Harris House
# 922         NaN                 Elihu Pease House
# 925         NaN                  Kensington Tower
# 931         NaN                       Clover Hill
# 932         NaN                     Elmsley Villa
# 933         NaN                     Vaughn Estate
# 934         NaN                      McLean House
# 936         NaN                      Glendon Hall
# 938         NaN                        Windfields
# 940         NaN                     Melrose House
# 941         NaN                       Houle House
# 955         NaN                Sheldon Ward House
# 958         NaN                         Pinehurst
# 959         NaN                       Devon House
# 961         NaN                       Devon House
# 962         NaN                George Brown House
# 974         NaN                         Blythwood
# 975         NaN                     Rebanks House
# 976         NaN                   Mackenzie House
# 983         NaN                James Harris House
# 984         NaN               Robert Powell House
# 985         NaN      William Peyton Hubbard House
# 989         NaN                          Wynyates
# 990         NaN              Joseph Shepard House
# 992         NaN                     Donalda Farms
# ...         ...                               ...
# 1331        NaN                         Runnymead
# 1332        NaN                         Roselands
# 1337        NaN  Moss Park (William Allan Estate)
# 1340        NaN          John Ross Robertson Home
# 1349        NaN                     Spadina House
# 1356        NaN                        Flag Court
# 1357        NaN                       Buena Vista
# 1360        NaN                    Chadwick House
# 1361        NaN                     Newman Centre
# 1369        NaN                       Dutch House
# 1372        NaN                        Cube House
# 1374        NaN                     Witch's House
# 1376        NaN                          Sunlands
# 1384        NaN               Mary Pickford House
# 1385        NaN                     Victory House
# 1388        NaN         Charles R. Peterkin House
# 1396        NaN                         Amblecote
# 1400        NaN                      Harper House
# 1404        NaN                   Paul Kane House
# 1409        NaN                         Owl House
# 1419        NaN                       Trend House
# 1423        NaN              Charles Parson House
# 1433        NaN                          Woodlawn
# 1435        NaN                        Munk House
# 1436        NaN                           Kineras
# 1439        NaN     Robert Baldwin Sullivan House
# 1440        NaN             Chestnut Park (house)
# 1443        NaN                C.W. Jefferys Home
# 1444        NaN                      Gibson House
# 1447        NaN    Robert Dirstien & Partners Ltd
#
#                                                  Notes: Type of Building:
# 893   Twinned double house also includes no.13 Admir...            Houses
# 897                                                 NaN            Houses
# 907                       Built for Theodore Heintzman.            Houses
# 908   Former owners were William Stewart and then Ro...            Houses
# 915                                                 NaN            Houses
# 919                                                 NaN            Houses
# 922                                                 NaN            Houses
# 925                                                 NaN            Houses
# 931                               Built by John Elmsley            Houses
# 932   Built for John Elmsley.  Functioned as the fou...            Houses
# 933   Built for Johm James Vaughan.  Initially known...            Houses
# 934   Built for James Stanley McLean (1876-1954) and...            Houses
# 936                                Built for E.R. Wood.            Houses
# 938   Built for E. P. Taylor.  Now functions as the ...            Houses
# 940                                                 NaN            Houses
# 941                                                 NaN            Houses
# 955                                                 NaN            Houses
# 958                                                 NaN            Houses
# 959                      SEE:  no. 152 Beverley Street.            Houses
# 961   Originally the home of John Cawthra.  Street a...            Houses
# 962                         Also known as Lambton Lodge            Houses
# 974                                                 NaN            Houses
# 975                                                 NaN            Houses
# 976   Home of William Lyon Mackenzie -- first mayor ...            Houses
# 983                                                 NaN            Houses
# 984                                                 NaN            Houses
# 985             Home of Toronto's first black alderman.            Houses
# 989                 Built for Colonel W. Eric Phillips.            Houses
# 990                                                 NaN            Houses
# 992   Built for David Dunlap.  House was substantial...            Houses
# ...                                                 ...               ...
# 1331                                                NaN            Houses
# 1332                              HOme of Samuel Ridout            Houses
# 1337            Home of William Allan (1772-1853).  The            Houses
# 1340  House also known as "Culloden".  John Ross Rob...            Houses
# 1349           Third of three houses built on the site.            Houses
# 1356            Originally the home of John Firstbrook.            Houses
# 1357                                                NaN            Houses
# 1360                              University of Toronto            Houses
# 1361  Originally the home of Toronto businessman Wil...            Houses
# 1369                                                NaN            Houses
# 1372                   Also known as a "Pole Dwelling".            Houses
# 1374      Reason for this house's nick-name is unknown.            Houses
# 1376                Owners: Mr. & Mrs. Beverley Balmer.            Houses
# 1384                                                NaN            Houses
# 1385  "Victory" homes were usually smaller, lower-co...            Houses
# 1388                                                NaN            Houses
# 1396              Originally the James P. Watson house.            Houses
# 1400                                                NaN            Houses
# 1404                                                NaN            Houses
# 1409  Built for commercial artist Charles W. Jeffrey...            Houses
# 1419  Formerly the home of Eric Arthur, noted author...            Houses
# 1423                                                NaN            Houses
# 1433  Toronto's second-oldest residence still in use...            Houses
# 1435                                                NaN            Houses
# 1436                                                NaN            Houses
# 1439                                                NaN            Houses
# 1440  Home of David Lewis MacPherson.  Situated on t...            Houses
# 1443  Built by local road-builder William Marshall. ...            Houses
# 1444                                                NaN            Houses
# 1447                  Originally the John Daniels house            Houses
#
# [132 rows x 7 columns]

# %%
db=connect_db() #establish connection
Session = sessionmaker(bind=db)
session = Session()

# %%
df_to_db_map={
    'Name of Building:':'name',
    'Building completed':'build_year'   ,
    'Demolished' :'demolished_year',
    'Address:' :'address' ,
    'Bld_link':'external_url',
    'Notes:': 'details',
    'Type of Building:':'poi_type'
}

# %%
if populate_db:
    save_to_database_ORM(session, bld_df)
